# %%
# !pip install datadotworld
# !pip install datadotworld[pandas]
# !pip install datadotworld
# !pip install datadotworld[pandas]
# Out:
# Collecting datadotworld
#   Downloading https://files.pythonhosted.org/packages/eb/2d/564c9b9056c414528f7a91c48bc33f2243bd5323ac07d52269002bd3d6c6/datadotworld-1.7.0-py2.py3-none-any.whl (158kB)
#      |████████████████████████████████| 163kB 2.8MB/s
# Collecting datapackage<2.0a,>=1.6.2
#   Downloading https://files.pythonhosted.org/packages/7e/cf/7900da3d259518e2b757935e4fb8796f96b615dda84c1805bf9e380a9433/datapackage-1.14.1-py2.py3-none-any.whl (85kB)
#      |████████████████████████████████| 92kB 5.5MB/s
# Requirement already satisfied: urllib3<2.0a,>=1.15 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (1.24.3)
# Collecting tabulator>=1.22.0
#   Downloading https://files.pythonhosted.org/packages/1d/12/22a346e531f25e97f303118adbad3a4ddfc453950030ee35e8386e2c6aaf/tabulator-1.52.3-py2.py3-none-any.whl (71kB)
#      |████████████████████████████████| 71kB 4.2MB/s
# Requirement already satisfied: requests<3.0a,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (2.23.0)
# Collecting configparser<4.0a,>=3.5.0
#   Downloading https://files.pythonhosted.org/packages/ab/1a/ec151e5e703ac80041eaccef923611bbcec2b667c20383655a06962732e9/configparser-3.8.1-py2.py3-none-any.whl
# Collecting click<7.0a,>=6.0
#   Downloading https://files.pythonhosted.org/packages/34/c1/8806f99713ddb993c5366c362b2f908f18269f8d792aff1abfd700775a77/click-6.7-py2.py3-none-any.whl (71kB)
#      |████████████████████████████████| 71kB 4.9MB/s
# Collecting tableschema<2.0a,>=1.5.2
#   Downloading https://files.pythonhosted.org/packages/4f/53/cc14214149c09e6d1f61078b97c87b6efb00e5e8de11d4d31419a1a8204d/tableschema-1.19.2-py2.py3-none-any.whl (68kB)
#      |████████████████████████████████| 71kB 4.7MB/s
# Requirement already satisfied: python-dateutil<3.0a,>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (2.8.1)
# Requirement already satisfied: certifi>=2017.04.17 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (2020.6.20)
# Requirement already satisfied: six<2.0a,>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld) (1.12.0)
# Collecting unicodecsv>=0.14
#   Downloading https://files.pythonhosted.org/packages/6f/a4/691ab63b17505a26096608cc309960b5a6bdf39e4ba1a793d5f9b1a53270/unicodecsv-0.14.1.tar.gz
# Requirement already satisfied: chardet>=3.0 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (3.0.4)
# Collecting jsonpointer>=1.10
#   Downloading https://files.pythonhosted.org/packages/18/b0/a80d29577c08eea401659254dfaed87f1af45272899e1812d7e01b679bc5/jsonpointer-2.0-py2.py3-none-any.whl
# Requirement already satisfied: jsonschema>=2.5 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld) (2.6.0)
# Collecting ijson>=3.0.3
#   Downloading https://files.pythonhosted.org/packages/b8/0b/e406ef9de26b2045f2ba689624d1844d1d8ffae991e0d2e792fde256e9ed/ijson-3.1.post0-cp36-cp36m-manylinux1_x86_64.whl (106kB)
#      |████████████████████████████████| 112kB 12.2MB/s
# Requirement already satisfied: sqlalchemy>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld) (1.3.17)
# Requirement already satisfied: xlrd>=1.0 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld) (1.1.0)
# Collecting openpyxl>=2.6
#   Downloading https://files.pythonhosted.org/packages/f9/d8/be9dc2b17ba47f1db9032ed7e19915145b4c093f66bb36f0d919d2dc8ccf/openpyxl-3.0.4-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 8.7MB/s
# Collecting jsonlines>=1.1
#   Downloading https://files.pythonhosted.org/packages/4f/9a/ab96291470e305504aa4b7a2e0ec132e930da89eb3ca7a82fbe03167c131/jsonlines-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: boto3>=1.9 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld) (1.14.9)
# Collecting linear-tsv>=1.0
#   Downloading https://files.pythonhosted.org/packages/82/e5/03207a0f11e1d60df85b97b61704ed701b725a7c2feaf83f7bfbd0c2d83e/linear-tsv-1.1.0.tar.gz
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0a,>=2.0.0->datadotworld) (2.9)
# Collecting isodate>=0.5.4
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 5.1MB/s
# Collecting rfc3986>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/78/be/7b8b99fd74ff5684225f50dd0e865393d2265656ef3b4ba9eaaaffe622b8/rfc3986-1.4.0-py2.py3-none-any.whl
# Collecting cached-property>=1.5
#   Downloading https://files.pythonhosted.org/packages/3b/86/85c1be2e8db9e13ef9a350aecd6dea292bd612fa288c2f40d035bb750ded/cached_property-1.5.1-py2.py3-none-any.whl
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.6/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld) (1.0.1)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.6/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld) (1.4.1)
# Requirement already satisfied: botocore<1.18.0,>=1.17.9 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (1.17.9)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld) (0.3.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.9->boto3>=1.9->tabulator>=1.22.0->datadotworld) (0.15.2)
# Building wheels for collected packages: unicodecsv, linear-tsv
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-cp36-none-any.whl size=10768 sha256=2b2505131b10b1ed09bd14b930affe95b2dd1b574a4bec376ca6827aadc145a4
#   Stored in directory: /root/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
#   Building wheel for linear-tsv (setup.py) ... done
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-cp36-none-any.whl size=7383 sha256=b7c7fbd83a8cc14d63d6183572a1c9fd8ee53ac52bfcc9ee599cb7d2712cf894
#   Stored in directory: /root/.cache/pip/wheels/3f/8a/cb/38917fd1ef4356b9870ace7331b83417dc594bf2c029bd991f
# Successfully built unicodecsv linear-tsv
# ERROR: pip-tools 4.5.1 has requirement click>=7, but you'll have click 6.7 which is incompatible.
# Installing collected packages: isodate, unicodecsv, rfc3986, click, cached-property, ijson, openpyxl, jsonlines, linear-tsv, tabulator, tableschema, jsonpointer, datapackage, configparser, datadotworld
#   Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# Successfully installed cached-property-1.5.1 click-6.7 configparser-3.8.1 datadotworld-1.7.0 datapackage-1.14.1 ijson-3.1.post0 isodate-0.6.0 jsonlines-1.2.0 jsonpointer-2.0 linear-tsv-1.1.0 openpyxl-3.0.4 rfc3986-1.4.0 tableschema-1.19.2 tabulator-1.52.3 unicodecsv-0.14.1
# Requirement already satisfied: datadotworld[pandas] in /usr/local/lib/python3.6/dist-packages (1.7.0)
# Requirement already satisfied: six<2.0a,>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.12.0)
# Requirement already satisfied: certifi>=2017.04.17 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (2020.6.20)
# Requirement already satisfied: datapackage<2.0a,>=1.6.2 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.14.1)
# Requirement already satisfied: requests<3.0a,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (2.23.0)
# Requirement already satisfied: configparser<4.0a,>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (3.8.1)
# Requirement already satisfied: click<7.0a,>=6.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (6.7)
# Requirement already satisfied: python-dateutil<3.0a,>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (2.8.1)
# Requirement already satisfied: tabulator>=1.22.0 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.52.3)
# Requirement already satisfied: urllib3<2.0a,>=1.15 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.24.3)
# Requirement already satisfied: tableschema<2.0a,>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from datadotworld[pandas]) (1.19.2)
# Collecting numpy<=1.16.4; extra == "pandas"
#   Downloading https://files.pythonhosted.org/packages/87/2d/e4656149cbadd3a8a0369fcd1a9c7d61cc7b87b3903b85389c70c989a696/numpy-1.16.4-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 1.2MB/s
# Collecting pandas<0.25; extra == "pandas"
#   Downloading https://files.pythonhosted.org/packages/19/74/e50234bc82c553fecdbd566d8650801e3fe2d6d8c8d940638e3d8a7c5522/pandas-0.24.2-cp36-cp36m-manylinux1_x86_64.whl (10.1MB)
#      |████████████████████████████████| 10.1MB 46.0MB/s
# Requirement already satisfied: jsonschema>=2.5 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (2.6.0)
# Requirement already satisfied: unicodecsv>=0.14 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.10 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (2.0)
# Requirement already satisfied: chardet>=3.0 in /usr/local/lib/python3.6/dist-packages (from datapackage<2.0a,>=1.6.2->datadotworld[pandas]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0a,>=2.0.0->datadotworld[pandas]) (2.9)
# Requirement already satisfied: boto3>=1.9 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.14.9)
# Requirement already satisfied: jsonlines>=1.1 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.2.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.3.17)
# Requirement already satisfied: linear-tsv>=1.0 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.1.0)
# Requirement already satisfied: ijson>=3.0.3 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (3.1.post0)
# Requirement already satisfied: openpyxl>=2.6 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (3.0.4)
# Requirement already satisfied: xlrd>=1.0 in /usr/local/lib/python3.6/dist-packages (from tabulator>=1.22.0->datadotworld[pandas]) (1.1.0)
# Requirement already satisfied: isodate>=0.5.4 in /usr/local/lib/python3.6/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld[pandas]) (0.6.0)
# Requirement already satisfied: rfc3986>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld[pandas]) (1.4.0)
# Requirement already satisfied: cached-property>=1.5 in /usr/local/lib/python3.6/dist-packages (from tableschema<2.0a,>=1.5.2->datadotworld[pandas]) (1.5.1)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas<0.25; extra == "pandas"->datadotworld[pandas]) (2018.9)
# Requirement already satisfied: botocore<1.18.0,>=1.17.9 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (1.17.9)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (0.10.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.6/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld[pandas]) (1.0.1)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.6/dist-packages (from openpyxl>=2.6->tabulator>=1.22.0->datadotworld[pandas]) (1.4.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.9->boto3>=1.9->tabulator>=1.22.0->datadotworld[pandas]) (0.15.2)
# ERROR: xarray 0.15.1 has requirement pandas>=0.25, but you'll have pandas 0.24.2 which is incompatible.
# ERROR: umap-learn 0.4.4 has requirement numpy>=1.17, but you'll have numpy 1.16.4 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement pandas>=0.25.0, but you'll have pandas 0.24.2 which is incompatible.
# ERROR: mizani 0.6.0 has requirement pandas>=0.25.0, but you'll have pandas 0.24.2 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=1.0.0; python_version >= "3.0", but you'll have pandas 0.24.2 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, pandas
#   Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
# Successfully installed numpy-1.16.4 pandas-0.24.2

# %%
pwd
# Out:
# '/content'

# %%
# !dw configure
# !dw configure
# Out:
# API token (obtained at: https://data.world/settings/advanced): eyJhbGciOiJIUzUxMiJ9..8AtmQ1V4bVev7gT3iUum6fIVlc52IShQOxUkYMXxRYgwr5gZ9uu-keUrcaZ8PqOeBG0mzMwiKoDYIJ_K5xJ6gg

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import datadotworld as dw

# %%
# drive.mount("/content/drive")
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  matrix_one/  README.md

# %%
# !mkdir data

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
data
# Out:
# LocalDataset('/root/.dw/cache/datafiniti/mens-shoe-prices/latest/datapackage.json')

# %%
data.dataframes

df = data.dataframes['7004_1']
df.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id asins           brand  ...  vin websiteids  weight
# 4742   AVpe420cilAPnD_xQIcb   NaN          Clarks  ...  NaN        NaN     NaN
# 10798  AVpfkVV61cnluZ0-nH8j   NaN           Sanuk  ...  NaN        NaN     NaN
# 15032  AVpfgDenLJeJML43-UF3   NaN         Merrell  ...  NaN        NaN     NaN
# 16693  AVpfo08SLJeJML43A8bw   NaN    Anchor Brand  ...  NaN        NaN     NaN
# 4191   AVpfRLqd1cnluZ0-heeB   NaN  Dan Post Boots  ...  NaN        NaN     NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df.prices_currency.value_counts()
# Out:
# USD                                                   18524
# AUD                                                     338
# CAD                                                     303
# EUR                                                     107
# GBP                                                      22
# PalmBeach Jewelry - Walmart.com                           3
# New with box                                              3
# UnbeatableSale.com, Inc. - Walmart.com                    3
# new                                                       3
# Wholesale Costume and Party Supplies - Walmart.com        2
# New without tags                                          1
# SHOEBACCA LTD. - Walmart.com                              1
# Shoes.com                                                 1
# Name: prices_currency, dtype: int64

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# PalmBeach Jewelry - Walmart.com                       0.000155
# New with box                                          0.000155
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# new                                                   0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# New without tags                                      0.000052
# SHOEBACCA LTD. - Walmart.com                          0.000052
# Shoes.com                                             0.000052
# Name: prices_currency, dtype: float64

# %%
df_usd = df[df.prices_currency == 'USD'].copy()
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd.prices_amountmin.head()
# Out:
# 0    39.89
# 1    51.99
# 2    40.02
# 3    50.31
# 4    46.26
# Name: prices_amountmin, dtype: object

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
np.percentile ( df_usd['prices_amountmin'], 99)
# Out:
# 895.0

# %%
filter_max = np.percentile( df_usd['prices_amountmin'], 99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[ df_usd['prices_amountmin'] < filter_max]

# %%
df_usd_filter.prices_amountmin.hist()

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
# !git add matrix_one/day3.ipynb

# %%
# !git commit -m "Read Men's Shoe Prices dataset from data.world"
# Out:
# [master 70fd2ca] Read Men's Shoe Prices dataset from data.world
#  2 files changed, 2 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 matrix_one/day3.ipynb

# %%
# !git config --global user.email "stanislaw.chmist@gmail.com"
# !git config --global user.name "Stanislaw"

# %%
# !git commit -m "Read Men's Shoe Prices dataset from data.world"
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Changes not staged for commit:
# 	modified:   ../HelloGithub.ipynb
# 	modified:   day3.ipynb
#
# no changes added to commit

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/dw_matrix'

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  matrix_one/  README.md

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  matrix_one/  README.md

# %%
cd matrix_one/
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_one

# %%
ls
# Out:
# day3.ipynb

# %%
# !git push -u origin master
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
pwd
# Out:
# '/content'
